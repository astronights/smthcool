# %%
import pandas as pd
import numpy as np

# %%
import allel # ref - https://scikit-allel.readthedocs.io/en/stable/io.html#variant-call-format-vcf

# %%
vcf_folder = "../dataset/"
vcf_file_freebayes = "syn1-freebayes.vcf.gz"
vcf_file_mutect = "syn1-mutect2.vcf.gz"
vcf_file_vardict = "syn1-vardict.vcf.gz"
vcf_file_varscan = "syn1-varscan.vcf.gz"

# %%
df_freebayes = allel.vcf_to_dataframe(vcf_folder + vcf_file_freebayes)

# %%
df_freebayes.head()
# Out:
#   CHROM    POS                       ID REF ALT_1 ALT_2 ALT_3        QUAL  \
# 0     1  10352  rs555500075;rs145072688   T    TA   NaN   NaN  273.500000
# 1     1  10583               rs58108140   G     A   NaN   NaN   40.500000
# 2     1  12783               rs62635284   G     A   NaN   NaN   61.000000
# 3     1  13550              rs554008981   G     A   NaN   NaN   36.599998
# 4     1  13668                rs2691328   G     A   NaN   NaN   36.000000
#
#    FILTER_PASS
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
df_mutect = allel.vcf_to_dataframe(vcf_folder + vcf_file_mutect)
df_mutect.head()
# Out:
#   CHROM    POS           ID REF ALT_1  ALT_2  ALT_3  QUAL  FILTER_PASS
# 0     1  13079   rs78890234   C     G    NaN    NaN   NaN        False
# 1     1  14653   rs62635297   C     T    NaN    NaN   NaN        False
# 2     1  16125   rs80224649   T     G    NaN    NaN   NaN        False
# 3     1  16288  rs113141985   C     G    NaN    NaN   NaN        False
# 4     1  16737            .   G     T    NaN    NaN   NaN        False

# %%
df_vardict = allel.vcf_to_dataframe(vcf_folder + vcf_file_vardict)
df_vardict.head()
# Out:
#   CHROM    POS                       ID REF ALT_1  ALT_2  ALT_3   QUAL  \
# 0     1  10180              rs201694901   T     C    NaN    NaN   67.0
# 1     1  10230              rs775928745  AC     A    NaN    NaN   79.0
# 2     1  10254                        .  TA    CT    NaN    NaN   72.0
# 3     1  10329              rs150969722  AC     A    NaN    NaN   80.0
# 4     1  10352  rs555500075;rs145072688   T    TA    NaN    NaN  148.0
#
#    FILTER_PASS
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False

# %%
df_varscan = allel.vcf_to_dataframe(vcf_folder + vcf_file_varscan)
df_varscan.head()
# Out:
#   CHROM    POS           ID REF ALT_1  ALT_2  ALT_3  QUAL  FILTER_PASS
# 0     1  10146  rs779258992  AC     A    NaN    NaN   0.0        False
# 1     1  10177  rs367896724   A    AC    NaN    NaN   0.0        False
# 2     1  10230  rs775928745  AC     A    NaN    NaN   0.0        False
# 3     1  10247  rs796996180   T     C    NaN    NaN   0.0        False
# 4     1  10248  rs148908337   A     T    NaN    NaN   0.0        False

# %%
print(f"Real freebayes shape = {df_freebayes.shape}")
print(f"Real Mutect shape = {df_mutect.shape}")
print(f"Real Vardict shape = {df_vardict.shape}")
print(f"Real Varscan shape = {df_varscan.shape}")
# Out:
# Real freebayes shape = (4744491, 9)
# Real Mutect shape = (107124, 9)
# Real Vardict shape = (4778259, 9)
# Real Varscan shape = (4718826, 9)

# %%
m1 = pd.merge(df_freebayes, df_mutect, on = ["CHROM", "POS"], how="outer", suffixes = ("_freebayes", "_mutect"))

# %%
m1.shape
# Out:
# (4840784, 16)

# %%
m2 = pd.merge(m1, df_vardict, on = ["CHROM", "POS"], how="outer")
m2.rename(columns={"ID": "ID_vardict", "REF": "REF_vardict", "ALT_1": "ALT_1_vardict", "ALT_2": "ALT_2_vardict", \
                  "ALT_3": "ALT_3_vardict", "QUAL": "QUAL_vardict", "FILTER_PASS": "FILTER_PASS_vardict"}, inplace=True)

# %%
m2.head()
# Out:
#   CHROM    POS             ID_freebayes REF_freebayes ALT_1_freebayes  \
# 0     1  10352  rs555500075;rs145072688             T              TA
# 1     1  10583               rs58108140             G               A
# 2     1  12783               rs62635284             G               A
# 3     1  13550              rs554008981             G               A
# 4     1  13668                rs2691328             G               A
#
#   ALT_2_freebayes ALT_3_freebayes  QUAL_freebayes FILTER_PASS_freebayes  \
# 0             NaN             NaN      273.500000                 False
# 1             NaN             NaN       40.500000                 False
# 2             NaN             NaN       61.000000                 False
# 3             NaN             NaN       36.599998                 False
# 4             NaN             NaN       36.000000                 False
#
#   ID_mutect  ... ALT_3_mutect QUAL_mutect  FILTER_PASS_mutect  \
# 0       NaN  ...          NaN         NaN                 NaN
# 1       NaN  ...          NaN         NaN                 NaN
# 2       NaN  ...          NaN         NaN                 NaN
# 3       NaN  ...          NaN         NaN                 NaN
# 4       NaN  ...          NaN         NaN                 NaN
#
#                 ID_vardict  REF_vardict ALT_1_vardict ALT_2_vardict  \
# 0  rs555500075;rs145072688            T            TA           NaN
# 1               rs58108140            G             A           NaN
# 2               rs62635284            G             A           NaN
# 3              rs554008981            G             A           NaN
# 4                      NaN          NaN           NaN           NaN
#
#   ALT_3_vardict QUAL_vardict  FILTER_PASS_vardict
# 0           NaN        148.0                False
# 1           NaN         48.0                False
# 2           NaN        114.0                False
# 3           NaN        130.0                False
# 4           NaN          NaN                  NaN
#
# [5 rows x 23 columns]

# %%
m2.shape
# Out:
# (5194513, 23)

# %%
m3 = pd.merge(m2, df_varscan, on = ["CHROM", "POS"], how="outer")
m3.rename(columns={"ID": "ID_varscan", "REF": "REF_varscan", "ALT_1": "ALT_1_varscan", "ALT_2": "ALT_2_varscan", \
                  "ALT_3": "ALT_3_varscan", "QUAL": "QUAL_varscan", "FILTER_PASS": "FILTER_PASS_varscan"}, inplace=True)
m3.shape
# Out:
# (5539098, 30)

# %%
m3.head()
# Out:
#   CHROM    POS             ID_freebayes REF_freebayes ALT_1_freebayes  \
# 0     1  10352  rs555500075;rs145072688             T              TA
# 1     1  10583               rs58108140             G               A
# 2     1  12783               rs62635284             G               A
# 3     1  13550              rs554008981             G               A
# 4     1  13668                rs2691328             G               A
#
#   ALT_2_freebayes ALT_3_freebayes  QUAL_freebayes FILTER_PASS_freebayes  \
# 0             NaN             NaN      273.500000                 False
# 1             NaN             NaN       40.500000                 False
# 2             NaN             NaN       61.000000                 False
# 3             NaN             NaN       36.599998                 False
# 4             NaN             NaN       36.000000                 False
#
#   ID_mutect  ... ALT_3_vardict QUAL_vardict  FILTER_PASS_vardict  \
# 0       NaN  ...           NaN        148.0                False
# 1       NaN  ...           NaN         48.0                False
# 2       NaN  ...           NaN        114.0                False
# 3       NaN  ...           NaN        130.0                False
# 4       NaN  ...           NaN          NaN                  NaN
#
#                 ID_varscan  REF_varscan ALT_1_varscan ALT_2_varscan  \
# 0  rs555500075;rs145072688            T            TA           NaN
# 1                      NaN          NaN           NaN           NaN
# 2               rs62635284            G             A           NaN
# 3              rs554008981            G             A           NaN
# 4                rs2691328            G             A           NaN
#
#   ALT_3_varscan QUAL_varscan  FILTER_PASS_varscan
# 0           NaN          0.0                False
# 1           NaN          NaN                  NaN
# 2           NaN          0.0                False
# 3           NaN          0.0                False
# 4           NaN          0.0                False
#
# [5 rows x 30 columns]

# %%
m3.head()[["CHROM", "POS", "FILTER_PASS_freebayes", "FILTER_PASS_mutect", "FILTER_PASS_vardict", "FILTER_PASS_varscan"]]
# Out:
#   CHROM    POS FILTER_PASS_freebayes FILTER_PASS_mutect FILTER_PASS_vardict  \
# 0     1  10352                 False                NaN               False
# 1     1  10583                 False                NaN               False
# 2     1  12783                 False                NaN               False
# 3     1  13550                 False                NaN               False
# 4     1  13668                 False                NaN                 NaN
#
#   FILTER_PASS_varscan
# 0               False
# 1                 NaN
# 2               False
# 3               False
# 4               False

# %%
df_merged = m3

# %%
# add third category instead of False?
df_merged["FILTER_PASS_freebayes"].fillna(False, inplace=True)
df_merged["FILTER_PASS_vardict"].fillna(False, inplace=True)
df_merged["FILTER_PASS_mutect"].fillna(False, inplace=True)
df_merged["FILTER_PASS_varscan"].fillna(False, inplace=True)
df_merged.head()[["CHROM", "POS", "FILTER_PASS_freebayes", "FILTER_PASS_mutect", "FILTER_PASS_vardict", "FILTER_PASS_varscan"]]
# Out:
#   CHROM    POS  FILTER_PASS_freebayes  FILTER_PASS_mutect  \
# 0     1  10352                  False               False
# 1     1  10583                  False               False
# 2     1  12783                  False               False
# 3     1  13550                  False               False
# 4     1  13668                  False               False
#
#    FILTER_PASS_vardict  FILTER_PASS_varscan
# 0                False                False
# 1                False                False
# 2                False                False
# 3                False                False
# 4                False                False

# %%
truth = pd.read_csv(vcf_folder + "syn1_truth.bed", sep = "\t", header = None)
truth.columns = ["CHROM", "POS_START", "POS_END"]
truth.head()
# Out:
#   CHROM  POS_START  POS_END
# 0     1     455705   455705
# 1     1     902593   902593
# 2     1    1015437  1015437
# 3     1    1482500  1482500
# 4     1    2180360  2180360

# %%
(truth.POS_START == truth.POS_END).sum()
# Out:
# 3537

# %%
truth.shape
# Out:
# (3537, 3)

# %%
truth.merge(df_merged, left_on = ["CHROM", "POS_START"], right_on = ["CHROM", "POS"])
# this is smaller than the actual truth file indicating the all 4 variant callers missed to classify some true variants
# Out:
#      CHROM  POS_START    POS_END        POS ID_freebayes REF_freebayes  \
# 0        1     902593     902593     902593            .             C
# 1        1    1015437    1015437    1015437            .             C
# 2        1    1482500    1482500    1482500            .             G
# 3        1    2180360    2180360    2180360            .             G
# 4        1    5163342    5163342    5163342            .             T
# ...    ...        ...        ...        ...          ...           ...
# 3517     X  151686589  151686589  151686589            .             A
# 3518     X  151722237  151722237  151722237            .             T
# 3519     X  152131181  152131181  152131181            .             T
# 3520     X  153589984  153589984  153589984            .             A
# 3521     X  154327204  154327204  154327204            .             T
#
#      ALT_1_freebayes ALT_2_freebayes ALT_3_freebayes  QUAL_freebayes  ...  \
# 0                  T             NaN             NaN      306.600006  ...
# 1                  A             NaN             NaN      273.899994  ...
# 2                  T             NaN             NaN      299.500000  ...
# 3                  T             NaN             NaN      390.700012  ...
# 4                  A             NaN             NaN      209.500000  ...
# ...              ...             ...             ...             ...  ...
# 3517               G             NaN             NaN      276.500000  ...
# 3518               C             NaN             NaN      133.300003  ...
# 3519               A             NaN             NaN      508.299988  ...
# 3520               C             NaN             NaN      449.200012  ...
# 3521               A             NaN             NaN      164.899994  ...
#
#       ALT_3_vardict QUAL_vardict FILTER_PASS_vardict ID_varscan  REF_varscan  \
# 0               NaN        119.0                True          .            C
# 1               NaN        123.0                True          .            C
# 2               NaN        128.0                True          .            G
# 3               NaN        137.0                True          .            G
# 4               NaN        113.0                True          .            T
# ...             ...          ...                 ...        ...          ...
# 3517            NaN        128.0                True          .            A
# 3518            NaN         83.0                True          .            T
# 3519            NaN        156.0                True          .            T
# 3520            NaN        145.0                True          .            A
# 3521            NaN        107.0                True          .            T
#
#       ALT_1_varscan  ALT_2_varscan  ALT_3_varscan QUAL_varscan  \
# 0                 T            NaN            NaN          0.0
# 1                 A            NaN            NaN          0.0
# 2                 T            NaN            NaN          0.0
# 3                 T            NaN            NaN          0.0
# 4                 A            NaN            NaN          0.0
# ...             ...            ...            ...          ...
# 3517              G            NaN            NaN          0.0
# 3518              C            NaN            NaN          0.0
# 3519              A            NaN            NaN          0.0
# 3520              C            NaN            NaN          0.0
# 3521              A            NaN            NaN          0.0
#
#      FILTER_PASS_varscan
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ...                  ...
# 3517               False
# 3518               False
# 3519               False
# 3520               False
# 3521               False
#
# [3522 rows x 32 columns]

# %%
df_merged_with_truth = pd.merge(truth, df_merged, left_on=["CHROM", "POS_START"], right_on = ["CHROM", "POS"], how="outer")
df_merged_with_truth.head()
# Out:
#   CHROM  POS_START    POS_END        POS ID_freebayes REF_freebayes  \
# 0     1   455705.0   455705.0        NaN          NaN           NaN
# 1     1   902593.0   902593.0   902593.0            .             C
# 2     1  1015437.0  1015437.0  1015437.0            .             C
# 3     1  1482500.0  1482500.0  1482500.0            .             G
# 4     1  2180360.0  2180360.0  2180360.0            .             G
#
#   ALT_1_freebayes ALT_2_freebayes ALT_3_freebayes  QUAL_freebayes  ...  \
# 0             NaN             NaN             NaN             NaN  ...
# 1               T             NaN             NaN      306.600006  ...
# 2               A             NaN             NaN      273.899994  ...
# 3               T             NaN             NaN      299.500000  ...
# 4               T             NaN             NaN      390.700012  ...
#
#   ALT_3_vardict QUAL_vardict FILTER_PASS_vardict ID_varscan  REF_varscan  \
# 0           NaN          NaN                 NaN        NaN          NaN
# 1           NaN        119.0                True          .            C
# 2           NaN        123.0                True          .            C
# 3           NaN        128.0                True          .            G
# 4           NaN        137.0                True          .            G
#
#    ALT_1_varscan  ALT_2_varscan ALT_3_varscan QUAL_varscan FILTER_PASS_varscan
# 0            NaN            NaN           NaN          NaN                 NaN
# 1              T            NaN           NaN          0.0               False
# 2              A            NaN           NaN          0.0               False
# 3              T            NaN           NaN          0.0               False
# 4              T            NaN           NaN          0.0               False
#
# [5 rows x 32 columns]

# %%
df_merged_with_truth.shape
# Out:
# (5539113, 32)

# %%
def set_true_label(row):
    if str(row) == "nan":
        return False
    else:
        return True

# %%
df_merged_with_truth["truth"] = df_merged_with_truth["POS_START"].apply(lambda row:set_true_label(row))

# %%
extras_in_truth = df_merged_with_truth[df_merged_with_truth.POS.isna()].index
extras_in_truth
# Out:
# Int64Index([   0,  311,  433,  485,  859,  974, 1091, 1109, 1794, 2451, 3173,
#             3221, 3389, 3491, 3507],
#            dtype='int64')

# %%
df_merged_with_truth.drop(extras_in_truth, inplace=True)

# %%
df_merged_with_truth.isna().sum()
# Out:
# CHROM                          0
# POS_START                5535576
# POS_END                  5535576
# POS                            0
# ID_freebayes              794607
# REF_freebayes             794607
# ALT_1_freebayes           794607
# ALT_2_freebayes          5476355
# ALT_3_freebayes          5535779
# QUAL_freebayes            794609
# FILTER_PASS_freebayes          0
# ID_mutect                5431922
# REF_mutect               5431922
# ALT_1_mutect             5431922
# ALT_2_mutect             5539098
# ALT_3_mutect             5539098
# QUAL_mutect              5539098
# FILTER_PASS_mutect             0
# ID_vardict                744360
# REF_vardict               744360
# ALT_1_vardict             744360
# ALT_2_vardict            5539098
# ALT_3_vardict            5539098
# QUAL_vardict              744422
# FILTER_PASS_vardict            0
# ID_varscan                806455
# REF_varscan               806455
# ALT_1_varscan             806455
# ALT_2_varscan            5539098
# ALT_3_varscan            5539098
# QUAL_varscan              806455
# FILTER_PASS_varscan            0
# truth                          0
# dtype: int64

# %%
df_merged_with_truth["QUAL_freebayes"].fillna(df_merged_with_truth["QUAL_freebayes"].mean(), inplace=True)
df_merged_with_truth["QUAL_vardict"].fillna(df_merged_with_truth["QUAL_vardict"].mean(), inplace=True)

# %%
df_merged_with_truth["QUAL_mutect"].isna().sum()
# Out:
# 5539098

# %%
df_merged_with_truth[["QUAL_freebayes", "QUAL_vardict"]].corr()
# Out:
#                 QUAL_freebayes  QUAL_vardict
# QUAL_freebayes        1.000000      0.392829
# QUAL_vardict          0.392829      1.000000

# %% [markdown]
# #### Confusion matrix comparing against truth

# %%
from sklearn.metrics import confusion_matrix

# %%
tn, fp, fn, tp = confusion_matrix(list(df_merged_with_truth.truth), list(df_merged_with_truth.FILTER_PASS_freebayes)).ravel()
tn, fp, fn, tp
# Out:
# (5525337, 10239, 85, 3437)

# %%
# least false positives
tn, fp, fn, tp = confusion_matrix(list(df_merged_with_truth.truth), list(df_merged_with_truth.FILTER_PASS_mutect)).ravel()
tn, fp, fn, tp
# Out:
# (5528210, 7366, 34, 3488)

# %%
tn, fp, fn, tp = confusion_matrix(list(df_merged_with_truth.truth), list(df_merged_with_truth.FILTER_PASS_vardict)).ravel()
tn, fp, fn, tp
# Out:
# (5514785, 20791, 45, 3477)

# %%
tn, fp, fn, tp = confusion_matrix(list(df_merged_with_truth.truth), list(df_merged_with_truth.FILTER_PASS_varscan)).ravel()
tn, fp, fn, tp
# Out:
# (5476697, 58879, 3334, 188)

# %%
def predict_label_three_best(row):
    if row["FILTER_PASS_mutect"] == False:
        return False
    if int(row["FILTER_PASS_freebayes"]) + int(row["FILTER_PASS_vardict"]) + int(row["FILTER_PASS_varscan"]) >= 2:
        return True
    return False

# %%
df_merged_with_truth["three_best_mutect_true"] = df_merged_with_truth[["FILTER_PASS_freebayes", "FILTER_PASS_mutect", "FILTER_PASS_vardict", "FILTER_PASS_varscan"]].apply(predict_label_three_best, axis = 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_merged_with_truth[["FILTER_PASS_mutect", "FILTER_PASS_freebayes", "FILTER_PASS_vardict", "FILTER_PASS_varscan"]], df_merged_with_truth["truth"], test_size = 0.2, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4431278, 4)
# (1107820, 4)
# (4431278,)
# (1107820,)

# %%
from pgmpy.models import BayesianNetwork

# %%
bn = BayesianNetwork(
[
#     ("CHROM", "truth"),
#     ("POS", "truth"),
#     ("QUAL_freebayes", "truth"),
#     ("QUAL_vardict", "truth"),
    ("FILTER_PASS_mutect", "truth"),
    ("FILTER_PASS_freebayes", "truth"),
    ("FILTER_PASS_vardict", "truth"),
    ("FILTER_PASS_varscan", "truth"),
])

# %%
from pgmpy.estimators import MaximumLikelihoodEstimator

# %%
train_df = pd.DataFrame(X_train, columns = ["FILTER_PASS_mutect","FILTER_PASS_freebayes", "FILTER_PASS_vardict", "FILTER_PASS_varscan"])
train_df["truth"] = y_train
print(train_df.shape)
train_df.head()
# Out:
# (4431278, 5)
#         FILTER_PASS_mutect FILTER_PASS_freebayes FILTER_PASS_vardict  \
# 3883414              False                 False               False
# 309031               False                 False               False
# 2723459              False                 False               False
# 3348473              False                 False               False
# 4183182              False                 False               False
#
#         FILTER_PASS_varscan  truth
# 3883414               False  False
# 309031                False  False
# 2723459               False  False
# 3348473               False  False
# 4183182               False  False

# %%
bn.fit(
    data=train_df,
    estimator=MaximumLikelihoodEstimator
)

# %%
print(bn.get_cpds("truth"))
# Out:
# +-----------------------+-----+-----------------------------+
# | FILTER_PASS_freebayes | ... | FILTER_PASS_freebayes(True) |
# +-----------------------+-----+-----------------------------+
# | FILTER_PASS_mutect    | ... | FILTER_PASS_mutect(True)    |
# +-----------------------+-----+-----------------------------+
# | FILTER_PASS_vardict   | ... | FILTER_PASS_vardict(True)   |
# +-----------------------+-----+-----------------------------+
# | FILTER_PASS_varscan   | ... | FILTER_PASS_varscan(True)   |
# +-----------------------+-----+-----------------------------+
# | truth(False)          | ... | 0.40654205607476634         |
# +-----------------------+-----+-----------------------------+
# | truth(True)           | ... | 0.5934579439252337          |
# +-----------------------+-----+-----------------------------+

# %%
test_df = pd.DataFrame(X_test, columns = ["FILTER_PASS_mutect","FILTER_PASS_freebayes", "FILTER_PASS_vardict", "FILTER_PASS_varscan"])
test_df["truth"] = y_test
print(test_df.shape)
test_df.head()
# Out:
# (1107820, 5)
#         FILTER_PASS_mutect FILTER_PASS_freebayes FILTER_PASS_vardict  \
# 1563251              False                 False               False
# 4871766              False                 False               False
# 2597386              False                 False               False
# 3862599              False                 False               False
# 343143               False                 False               False
#
#         FILTER_PASS_varscan  truth
# 1563251               False  False
# 4871766               False  False
# 2597386               False  False
# 3862599               False  False
# 343143                False  False

# %%
from pgmpy.inference import VariableElimination
from ipywidgets import FloatProgress

# %%
bn_infer = VariableElimination(bn)

# %%
from IPython.display import clear_output

# %%
def get_preds(row):
    prob = bn_infer.query(variables=["truth"], evidence={"FILTER_PASS_freebayes": row["FILTER_PASS_freebayes"], \
                                             "FILTER_PASS_mutect": row["FILTER_PASS_mutect"], \
                                             "FILTER_PASS_vardict": row["FILTER_PASS_vardict"], \
                                             "FILTER_PASS_varscan": row["FILTER_PASS_varscan"]}, show_progress=False)
#     clear_output(wait=True)
    if (prob.values[1]) > 0.5:
        return True
    else:
        return False

# %%
test_df["preds"] = test_df.apply(get_preds, axis = 1)

# %% [markdown]
# #### Metric evaluation

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(df_merged_with_truth["truth"], df_merged_with_truth["three_best_mutect_true"]))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00   5535576
#         True       0.87      0.97      0.92      3522
#
#     accuracy                           1.00   5539098
#    macro avg       0.94      0.98      0.96   5539098
# weighted avg       1.00      1.00      1.00   5539098

# %%
print(classification_report(test_df["truth"], test_df["preds"]))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00   1107112
#         True       0.92      0.97      0.95       708
#
#     accuracy                           1.00   1107820
#    macro avg       0.96      0.99      0.97   1107820
# weighted avg       1.00      1.00      1.00   1107820

# %%
df_merged_with_truth.shape
# Out:
# (5539098, 34)
