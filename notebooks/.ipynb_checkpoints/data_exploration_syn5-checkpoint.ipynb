# %%
import pandas as pd
import numpy as np

# %%
import allel # ref - https://scikit-allel.readthedocs.io/en/stable/io.html#variant-call-format-vcf

# %%
vcf_folder = "../dataset/"
vcf_file_freebayes = "syn5-freebayes.vcf.gz"
vcf_file_mutect = "syn5-mutect2.vcf.gz"
vcf_file_vardict = "syn5-vardict.vcf.gz"
vcf_file_varscan = "syn5-varscan.vcf.gz"

# %%
df_freebayes = allel.vcf_to_dataframe(vcf_folder + vcf_file_freebayes)

# %%
df_freebayes.head()
# Out:
#   CHROM    POS            ID REF ALT_1 ALT_2 ALT_3        QUAL  FILTER_PASS
# 0     1  10057             .   A    AC   NaN   NaN   56.900002        False
# 1     1  10248   rs148908337   A     T   NaN   NaN  178.899994        False
# 2     1  10255  rs1015259029   A     T   NaN   NaN  193.399994        False
# 3     1  10260             .   C    CT   NaN   NaN   61.599998        False
# 4     1  10427             .   A    AC   NaN   NaN   65.199997        False

# %%
df_mutect = allel.vcf_to_dataframe(vcf_folder + vcf_file_mutect)
df_mutect.head()
# Out:
#   CHROM     POS            ID REF ALT_1  ALT_2  ALT_3  QUAL  FILTER_PASS
# 0     1  674456    rs77806715   G     A    NaN    NaN   NaN        False
# 1     1  726156   rs796779711   T     A    NaN    NaN   NaN        False
# 2     1  726173             .   G     A    NaN    NaN   NaN        False
# 3     1  726183  rs1000851233   C     A    NaN    NaN   NaN        False
# 4     1  726185   rs111203408   T     A    NaN    NaN   NaN        False

# %%
df_vardict = allel.vcf_to_dataframe(vcf_folder + vcf_file_vardict)
df_vardict.head()
# Out:
#   CHROM    POS            ID                       REF ALT_1  ALT_2  ALT_3  \
# 0     1  10248   rs148908337                         A     T    NaN    NaN
# 1     1  10255  rs1015259029                         A     T    NaN    NaN
# 2     1  10404             .  CCCTAACCCTAACCCTAACCCTAA     C    NaN    NaN
# 3     1  10439   rs112766696                        AC     A    NaN    NaN
# 4     1  10583    rs58108140                         G     A    NaN    NaN
#
#    QUAL  FILTER_PASS
# 0  42.0        False
# 1  48.0        False
# 2  35.0        False
# 3  63.0        False
# 4  67.0        False

# %%
df_varscan = allel.vcf_to_dataframe(vcf_folder + vcf_file_varscan)
df_varscan.head()
# Out:
#   CHROM    POS                       ID REF ALT_1  ALT_2  ALT_3  QUAL  \
# 0     1  10150              rs371194064   C     T    NaN    NaN   0.0
# 1     1  10352  rs555500075;rs145072688   T    TA    NaN    NaN   0.0
# 2     1  10427                        .   A    AC    NaN    NaN   0.0
# 3     1  10583               rs58108140   G     A    NaN    NaN   0.0
# 4     1  14464              rs546169444   A     T    NaN    NaN   0.0
#
#    FILTER_PASS
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
print(f"Real freebayes shape = {df_freebayes.shape}")
print(f"Real Mutect shape = {df_mutect.shape}")
print(f"Real Vardict shape = {df_vardict.shape}")
print(f"Real Varscan shape = {df_varscan.shape}")
# Out:
# Real freebayes shape = (4621247, 9)
# Real Mutect shape = (116115, 9)
# Real Vardict shape = (4502129, 9)
# Real Varscan shape = (4368655, 9)

# %%
m1 = pd.merge(df_freebayes, df_mutect, on = ["CHROM", "POS"], how="outer", suffixes = ("_freebayes", "_mutect"))

# %%
m1.shape
# Out:
# (4682646, 16)

# %%
m2 = pd.merge(m1, df_vardict, on = ["CHROM", "POS"], how="outer")
m2.rename(columns={"ID": "ID_vardict", "REF": "REF_vardict", "ALT_1": "ALT_1_vardict", "ALT_2": "ALT_2_vardict", \
                  "ALT_3": "ALT_3_vardict", "QUAL": "QUAL_vardict", "FILTER_PASS": "FILTER_PASS_vardict"}, inplace=True)

# %%
m2.head()
# Out:
#   CHROM    POS  ID_freebayes REF_freebayes ALT_1_freebayes ALT_2_freebayes  \
# 0     1  10057             .             A              AC             NaN
# 1     1  10248   rs148908337             A               T             NaN
# 2     1  10255  rs1015259029             A               T             NaN
# 3     1  10260             .             C              CT             NaN
# 4     1  10427             .             A              AC             NaN
#
#   ALT_3_freebayes  QUAL_freebayes FILTER_PASS_freebayes ID_mutect  ...  \
# 0             NaN       56.900002                 False       NaN  ...
# 1             NaN      178.899994                 False       NaN  ...
# 2             NaN      193.399994                 False       NaN  ...
# 3             NaN       61.599998                 False       NaN  ...
# 4             NaN       65.199997                 False       NaN  ...
#
#   ALT_3_mutect QUAL_mutect  FILTER_PASS_mutect    ID_vardict  REF_vardict  \
# 0          NaN         NaN                 NaN           NaN          NaN
# 1          NaN         NaN                 NaN   rs148908337            A
# 2          NaN         NaN                 NaN  rs1015259029            A
# 3          NaN         NaN                 NaN           NaN          NaN
# 4          NaN         NaN                 NaN           NaN          NaN
#
#   ALT_1_vardict ALT_2_vardict ALT_3_vardict QUAL_vardict  FILTER_PASS_vardict
# 0           NaN           NaN           NaN          NaN                  NaN
# 1             T           NaN           NaN         42.0                False
# 2             T           NaN           NaN         48.0                False
# 3           NaN           NaN           NaN          NaN                  NaN
# 4           NaN           NaN           NaN          NaN                  NaN
#
# [5 rows x 23 columns]

# %%
m2.shape
# Out:
# (4867809, 23)

# %%
m3 = pd.merge(m2, df_varscan, on = ["CHROM", "POS"], how="outer")
m3.rename(columns={"ID": "ID_varscan", "REF": "REF_varscan", "ALT_1": "ALT_1_varscan", "ALT_2": "ALT_2_varscan", \
                  "ALT_3": "ALT_3_varscan", "QUAL": "QUAL_varscan", "FILTER_PASS": "FILTER_PASS_varscan"}, inplace=True)
m3.shape
# Out:
# (4977710, 30)

# %%
m3.head()
# Out:
#   CHROM    POS  ID_freebayes REF_freebayes ALT_1_freebayes ALT_2_freebayes  \
# 0     1  10057             .             A              AC             NaN
# 1     1  10248   rs148908337             A               T             NaN
# 2     1  10255  rs1015259029             A               T             NaN
# 3     1  10260             .             C              CT             NaN
# 4     1  10427             .             A              AC             NaN
#
#   ALT_3_freebayes  QUAL_freebayes FILTER_PASS_freebayes ID_mutect  ...  \
# 0             NaN       56.900002                 False       NaN  ...
# 1             NaN      178.899994                 False       NaN  ...
# 2             NaN      193.399994                 False       NaN  ...
# 3             NaN       61.599998                 False       NaN  ...
# 4             NaN       65.199997                 False       NaN  ...
#
#   ALT_3_vardict QUAL_vardict  FILTER_PASS_vardict  ID_varscan  REF_varscan  \
# 0           NaN          NaN                  NaN         NaN          NaN
# 1           NaN         42.0                False         NaN          NaN
# 2           NaN         48.0                False         NaN          NaN
# 3           NaN          NaN                  NaN         NaN          NaN
# 4           NaN          NaN                  NaN           .            A
#
#   ALT_1_varscan ALT_2_varscan ALT_3_varscan QUAL_varscan  FILTER_PASS_varscan
# 0           NaN           NaN           NaN          NaN                  NaN
# 1           NaN           NaN           NaN          NaN                  NaN
# 2           NaN           NaN           NaN          NaN                  NaN
# 3           NaN           NaN           NaN          NaN                  NaN
# 4            AC           NaN           NaN          0.0                False
#
# [5 rows x 30 columns]

# %%
m3.head()[["CHROM", "POS", "FILTER_PASS_freebayes", "FILTER_PASS_mutect", "FILTER_PASS_vardict", "FILTER_PASS_varscan"]]
# Out:
#   CHROM    POS FILTER_PASS_freebayes FILTER_PASS_mutect FILTER_PASS_vardict  \
# 0     1  10057                 False                NaN                 NaN
# 1     1  10248                 False                NaN               False
# 2     1  10255                 False                NaN               False
# 3     1  10260                 False                NaN                 NaN
# 4     1  10427                 False                NaN                 NaN
#
#   FILTER_PASS_varscan
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4               False

# %%
df_merged = m3

# %%
# add third category instead of False?
df_merged["FILTER_PASS_freebayes"].fillna(False, inplace=True)
df_merged["FILTER_PASS_vardict"].fillna(False, inplace=True)
df_merged["FILTER_PASS_mutect"].fillna(False, inplace=True)
df_merged["FILTER_PASS_varscan"].fillna(False, inplace=True)
df_merged.head()[["CHROM", "POS", "FILTER_PASS_freebayes", "FILTER_PASS_mutect", "FILTER_PASS_vardict", "FILTER_PASS_varscan"]]
# Out:
#   CHROM    POS  FILTER_PASS_freebayes  FILTER_PASS_mutect  \
# 0     1  10057                  False               False
# 1     1  10248                  False               False
# 2     1  10255                  False               False
# 3     1  10260                  False               False
# 4     1  10427                  False               False
#
#    FILTER_PASS_vardict  FILTER_PASS_varscan
# 0                False                False
# 1                False                False
# 2                False                False
# 3                False                False
# 4                False                False

# %%
truth = pd.read_csv(vcf_folder + "syn5_truth.bed", sep = "\t", header = None)
truth.columns = ["CHROM", "POS_START", "POS_END"]
truth.head()
# Out:
#   CHROM  POS_START  POS_END
# 0     1     752211   752211
# 1     1     824652   824652
# 2     1     917467   917467
# 3     1    1016648  1016648
# 4     1    1038806  1038806

# %%
(truth.POS_START == truth.POS_END).sum()
# Out:
# 45383

# %%
truth.shape
# Out:
# (45383, 3)

# %%
truth.merge(df_merged, left_on = ["CHROM", "POS_START"], right_on = ["CHROM", "POS"])
# this is smaller than the actual truth file indicating the all 4 variant callers missed to classify some true variants
# Out:
#       CHROM  POS_START   POS_END       POS ID_freebayes REF_freebayes  \
# 0         1     752211    752211    752211            .             G
# 1         1     824652    824652    824652            .             T
# 2         1     917467    917467    917467            .             G
# 3         1    1016648   1016648   1016648          NaN           NaN
# 4         1    1038806   1038806   1038806            .             G
# ...     ...        ...       ...       ...          ...           ...
# 45089     Y   28483053  28483053  28483053          NaN           NaN
# 45090     Y   28656099  28656099  28656099            .             G
# 45091     Y   28713794  28713794  28713794            .             A
# 45092     Y   28762270  28762270  28762270          NaN           NaN
# 45093     Y   28813491  28813491  28813491          NaN           NaN
#
#       ALT_1_freebayes ALT_2_freebayes ALT_3_freebayes  QUAL_freebayes  ...  \
# 0                   C             NaN             NaN       11.400000  ...
# 1                   A             NaN             NaN      321.100006  ...
# 2                   T             NaN             NaN       32.099998  ...
# 3                 NaN             NaN             NaN             NaN  ...
# 4                   T             NaN             NaN      245.500000  ...
# ...               ...             ...             ...             ...  ...
# 45089             NaN             NaN             NaN             NaN  ...
# 45090               C             NaN             NaN      116.400002  ...
# 45091               T             NaN             NaN      143.699997  ...
# 45092             NaN             NaN             NaN             NaN  ...
# 45093             NaN             NaN             NaN             NaN  ...
#
#        ALT_3_vardict QUAL_vardict FILTER_PASS_vardict ID_varscan  REF_varscan  \
# 0                NaN         70.0                True          .            G
# 1                NaN        131.0                True          .            T
# 2                NaN         35.0               False          .            G
# 3                NaN         34.0               False        NaN          NaN
# 4                NaN        120.0                True          .            G
# ...              ...          ...                 ...        ...          ...
# 45089            NaN         33.0               False          .            A
# 45090            NaN        108.0                True          .            G
# 45091            NaN        119.0                True          .            A
# 45092            NaN         81.0                True          .            A
# 45093            NaN          NaN               False          .            A
#
#        ALT_1_varscan  ALT_2_varscan  ALT_3_varscan QUAL_varscan  \
# 0                  C            NaN            NaN          0.0
# 1                  A            NaN            NaN          0.0
# 2                  T            NaN            NaN          0.0
# 3                NaN            NaN            NaN          NaN
# 4                  T            NaN            NaN          0.0
# ...              ...            ...            ...          ...
# 45089              C            NaN            NaN          0.0
# 45090              C            NaN            NaN          0.0
# 45091              T            NaN            NaN          0.0
# 45092              C            NaN            NaN          0.0
# 45093              C            NaN            NaN          0.0
#
#       FILTER_PASS_varscan
# 0                    True
# 1                    True
# 2                    True
# 3                   False
# 4                    True
# ...                   ...
# 45089                True
# 45090               False
# 45091               False
# 45092               False
# 45093               False
#
# [45094 rows x 32 columns]

# %%
df_merged_with_truth = pd.merge(truth, df_merged, left_on=["CHROM", "POS_START"], right_on = ["CHROM", "POS"], how="outer")
df_merged_with_truth.head()
# Out:
#   CHROM  POS_START    POS_END        POS ID_freebayes REF_freebayes  \
# 0     1   752211.0   752211.0   752211.0            .             G
# 1     1   824652.0   824652.0   824652.0            .             T
# 2     1   917467.0   917467.0   917467.0            .             G
# 3     1  1016648.0  1016648.0  1016648.0          NaN           NaN
# 4     1  1038806.0  1038806.0  1038806.0            .             G
#
#   ALT_1_freebayes ALT_2_freebayes ALT_3_freebayes  QUAL_freebayes  ...  \
# 0               C             NaN             NaN       11.400000  ...
# 1               A             NaN             NaN      321.100006  ...
# 2               T             NaN             NaN       32.099998  ...
# 3             NaN             NaN             NaN             NaN  ...
# 4               T             NaN             NaN      245.500000  ...
#
#   ALT_3_vardict QUAL_vardict FILTER_PASS_vardict ID_varscan  REF_varscan  \
# 0           NaN         70.0                True          .            G
# 1           NaN        131.0                True          .            T
# 2           NaN         35.0               False          .            G
# 3           NaN         34.0               False        NaN          NaN
# 4           NaN        120.0                True          .            G
#
#    ALT_1_varscan  ALT_2_varscan ALT_3_varscan QUAL_varscan FILTER_PASS_varscan
# 0              C            NaN           NaN          0.0                True
# 1              A            NaN           NaN          0.0                True
# 2              T            NaN           NaN          0.0                True
# 3            NaN            NaN           NaN          NaN               False
# 4              T            NaN           NaN          0.0                True
#
# [5 rows x 32 columns]

# %%
df_merged_with_truth.shape
# Out:
# (4977999, 32)

# %%
def set_true_label(row):
    if str(row) == "nan":
        return False
    else:
        return True

# %%
df_merged_with_truth["truth"] = df_merged_with_truth["POS_START"].apply(lambda row:set_true_label(row))
df_merged_with_truth.sum()
# Out:
# CHROM                    1111111111111111111111111111111111111111111111...
# POS_START                                                  3679981132421.0
# POS_END                                                    3679981132421.0
# POS                                                      381301210632714.0
# QUAL_freebayes                                                4621751808.0
# FILTER_PASS_freebayes                                                52954
# ALT_2_mutect                                                           0.0
# ALT_3_mutect                                                           0.0
# QUAL_mutect                                                            0.0
# FILTER_PASS_mutect                                                   60046
# ALT_2_vardict                                                          0.0
# ALT_3_vardict                                                          0.0
# QUAL_vardict                                                   598664512.0
# FILTER_PASS_vardict                                                  58637
# ALT_2_varscan                                                          0.0
# ALT_3_varscan                                                          0.0
# QUAL_varscan                                                           0.0
# FILTER_PASS_varscan                                                  33941
# truth                                                                45383
# dtype: object

# %%
def decide_prediction(row):
    if row["FILTER_PASS_freebayes"] + row["FILTER_PASS_mutect"] + row["FILTER_PASS_vardict"] + row["FILTER_PASS_varscan"] >= 2:
        return True
    else:
        return False

# %%
df_merged_with_truth["preds"] = df_merged_with_truth.apply(lambda row: decide_prediction(row), axis = 1)

# %%
df_merged_with_truth["preds"].sum()
# Out:
# 59098

# %%
extras_in_truth = df_merged_with_truth[df_merged_with_truth.POS.isna()].index

# %%
df_merged_with_truth.drop(extras_in_truth, inplace=True)

# %%
def predict_label_three_best(row):
    if row["FILTER_PASS_mutect"] == False:
        return False
    if row["FILTER_PASS_freebayes"] + row["FILTER_PASS_vardict"] + row["FILTER_PASS_varscan"] >= 2:
        return True
    return False
df_merged_with_truth["three_best_mutect_true"] = df_merged_with_truth[["FILTER_PASS_freebayes", "FILTER_PASS_mutect", "FILTER_PASS_vardict", "FILTER_PASS_varscan"]].apply(predict_label_three_best, axis = 1)

# %%
from sklearn.metrics import f1_score, precision_score, recall_score
print(f'F1 score = {f1_score(df_merged_with_truth["truth"], df_merged_with_truth["preds"])}')
print(f'Precision = {precision_score(df_merged_with_truth["truth"], df_merged_with_truth["preds"])}')
print(f'Recall = {recall_score(df_merged_with_truth["truth"], df_merged_with_truth["preds"])}')
# Out:
# F1 score = 0.8426942567567568
# Precision = 0.7428508578970524
# Recall = 0.9735441522153724

# %%
from sklearn.metrics import classification_report
print(classification_report(df_merged_with_truth["truth"], df_merged_with_truth["preds"]))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00   4932616
#         True       0.74      0.97      0.84     45094
#
#     accuracy                           1.00   4977710
#    macro avg       0.87      0.99      0.92   4977710
# weighted avg       1.00      1.00      1.00   4977710

# %%
print(classification_report(df_merged_with_truth["truth"], df_merged_with_truth["three_best_mutect_true"]))
