# %%
import pandas as pd
import numpy as np

# %%
import allel # ref - https://scikit-allel.readthedocs.io/en/stable/io.html#variant-call-format-vcf

# %%
vcf_folder = "../dataset/"
vcf_file_freebayes = "syn3-freebayes.vcf.gz"
vcf_file_mutect = "syn3-mutect2.vcf.gz"
vcf_file_vardict = "syn3-vardict.vcf.gz"
vcf_file_varscan = "syn3-varscan.vcf.gz"

# %%
df_freebayes = allel.vcf_to_dataframe(vcf_folder + vcf_file_freebayes)

# %%
df_freebayes.head()
# Out:
#   CHROM    POS                       ID REF ALT_1 ALT_2 ALT_3        QUAL  \
# 0     1  10177              rs367896724   A    AC   NaN   NaN  233.199997
# 1     1  10352  rs555500075;rs145072688   T    TA   NaN   NaN  330.600006
# 2     1  10583               rs58108140   G     A   NaN   NaN   97.699997
# 3     1  10623                        .   T     C   NaN   NaN    9.600000
# 4     1  10649                        .   G     A   NaN   NaN   16.700001
#
#    FILTER_PASS
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False

# %%
df_mutect = allel.vcf_to_dataframe(vcf_folder + vcf_file_mutect)
df_mutect.head()
# Out:
#   CHROM     POS         ID REF ALT_1  ALT_2  ALT_3  QUAL  FILTER_PASS
# 0     1  137221          .   T     G    NaN    NaN   NaN        False
# 1     1  237762          .   G     A    NaN    NaN   NaN        False
# 2     1  252853  rs9699802   T     C    NaN    NaN   NaN        False
# 3     1  252873  rs9700554   G     A    NaN    NaN   NaN        False
# 4     1  526346          .   C     A    NaN    NaN   NaN        False

# %%
df_vardict = allel.vcf_to_dataframe(vcf_folder + vcf_file_vardict)
df_vardict.head()
# Out:
#   CHROM    POS                       ID REF ALT_1  ALT_2  ALT_3   QUAL  \
# 0     1  10231              rs200279319   C     A    NaN    NaN  111.0
# 1     1  10329              rs150969722  AC     A    NaN    NaN  160.0
# 2     1  10352  rs555500075;rs145072688   T    TA    NaN    NaN  148.0
# 3     1  10469              rs370233998   C     G    NaN    NaN   83.0
# 4     1  10519               rs62636508   G     C    NaN    NaN   70.0
#
#    FILTER_PASS
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
df_varscan = allel.vcf_to_dataframe(vcf_folder + vcf_file_varscan)
df_varscan.head()
# Out:
#   CHROM    POS           ID REF ALT_1  ALT_2  ALT_3  QUAL  FILTER_PASS
# 0     1  10177  rs367896724   A    AC    NaN    NaN   0.0        False
# 1     1  10230  rs775928745  AC     A    NaN    NaN   0.0        False
# 2     1  10234  rs145599635   C     T    NaN    NaN   0.0        False
# 3     1  10247            .  TA     T    NaN    NaN   0.0        False
# 4     1  10248  rs148908337   A     T    NaN    NaN   0.0        False

# %%
print(f"Real freebayes shape = {df_freebayes.shape}")
print(f"Real Mutect shape = {df_mutect.shape}")
print(f"Real Vardict shape = {df_vardict.shape}")
print(f"Real Varscan shape = {df_varscan.shape}")
# Out:
# Real freebayes shape = (4869534, 9)
# Real Mutect shape = (120023, 9)
# Real Vardict shape = (4911379, 9)
# Real Varscan shape = (4702513, 9)

# %%
m1 = pd.merge(df_freebayes, df_mutect, on = ["CHROM", "POS"], how="outer", suffixes = ("_freebayes", "_mutect"))

# %%
m1.shape
# Out:
# (4971952, 16)

# %%
m2 = pd.merge(m1, df_vardict, on = ["CHROM", "POS"], how="outer")
m2.rename(columns={"ID": "ID_vardict", "REF": "REF_vardict", "ALT_1": "ALT_1_vardict", "ALT_2": "ALT_2_vardict", \
                  "ALT_3": "ALT_3_vardict", "QUAL": "QUAL_vardict", "FILTER_PASS": "FILTER_PASS_vardict"}, inplace=True)

# %%
m2.head()
# Out:
#   CHROM    POS             ID_freebayes REF_freebayes ALT_1_freebayes  \
# 0     1  10177              rs367896724             A              AC
# 1     1  10352  rs555500075;rs145072688             T              TA
# 2     1  10583               rs58108140             G               A
# 3     1  10623                        .             T               C
# 4     1  10649                        .             G               A
#
#   ALT_2_freebayes ALT_3_freebayes  QUAL_freebayes FILTER_PASS_freebayes  \
# 0             NaN             NaN      233.199997                 False
# 1             NaN             NaN      330.600006                 False
# 2             NaN             NaN       97.699997                 False
# 3             NaN             NaN        9.600000                  True
# 4             NaN             NaN       16.700001                 False
#
#   ID_mutect  ... ALT_3_mutect QUAL_mutect  FILTER_PASS_mutect  \
# 0       NaN  ...          NaN         NaN                 NaN
# 1       NaN  ...          NaN         NaN                 NaN
# 2       NaN  ...          NaN         NaN                 NaN
# 3       NaN  ...          NaN         NaN                 NaN
# 4       NaN  ...          NaN         NaN                 NaN
#
#                 ID_vardict  REF_vardict ALT_1_vardict ALT_2_vardict  \
# 0                      NaN          NaN           NaN           NaN
# 1  rs555500075;rs145072688            T            TA           NaN
# 2               rs58108140            G             A           NaN
# 3                        .            T             C           NaN
# 4                        .            G             A           NaN
#
#   ALT_3_vardict QUAL_vardict  FILTER_PASS_vardict
# 0           NaN          NaN                  NaN
# 1           NaN        148.0                False
# 2           NaN         92.0                False
# 3           NaN         67.0                False
# 4           NaN         66.0                False
#
# [5 rows x 23 columns]

# %%
m2.shape
# Out:
# (5332326, 23)

# %%
m3 = pd.merge(m2, df_varscan, on = ["CHROM", "POS"], how="outer")
m3.rename(columns={"ID": "ID_varscan", "REF": "REF_varscan", "ALT_1": "ALT_1_varscan", "ALT_2": "ALT_2_varscan", \
                  "ALT_3": "ALT_3_varscan", "QUAL": "QUAL_varscan", "FILTER_PASS": "FILTER_PASS_varscan"}, inplace=True)
m3.shape
# Out:
# (5633087, 30)

# %%
m3.head()
# Out:
#   CHROM    POS             ID_freebayes REF_freebayes ALT_1_freebayes  \
# 0     1  10177              rs367896724             A              AC
# 1     1  10352  rs555500075;rs145072688             T              TA
# 2     1  10583               rs58108140             G               A
# 3     1  10623                        .             T               C
# 4     1  10649                        .             G               A
#
#   ALT_2_freebayes ALT_3_freebayes  QUAL_freebayes FILTER_PASS_freebayes  \
# 0             NaN             NaN      233.199997                 False
# 1             NaN             NaN      330.600006                 False
# 2             NaN             NaN       97.699997                 False
# 3             NaN             NaN        9.600000                  True
# 4             NaN             NaN       16.700001                 False
#
#   ID_mutect  ... ALT_3_vardict QUAL_vardict  FILTER_PASS_vardict  \
# 0       NaN  ...           NaN          NaN                  NaN
# 1       NaN  ...           NaN        148.0                False
# 2       NaN  ...           NaN         92.0                False
# 3       NaN  ...           NaN         67.0                False
# 4       NaN  ...           NaN         66.0                False
#
#                 ID_varscan  REF_varscan ALT_1_varscan ALT_2_varscan  \
# 0              rs367896724            A            AC           NaN
# 1  rs555500075;rs145072688            T            TA           NaN
# 2                      NaN          NaN           NaN           NaN
# 3                      NaN          NaN           NaN           NaN
# 4                      NaN          NaN           NaN           NaN
#
#   ALT_3_varscan QUAL_varscan  FILTER_PASS_varscan
# 0           NaN          0.0                False
# 1           NaN          0.0                False
# 2           NaN          NaN                  NaN
# 3           NaN          NaN                  NaN
# 4           NaN          NaN                  NaN
#
# [5 rows x 30 columns]

# %%
m3.head()[["CHROM", "POS", "FILTER_PASS_freebayes", "FILTER_PASS_mutect", "FILTER_PASS_vardict", "FILTER_PASS_varscan"]]
# Out:
#   CHROM    POS FILTER_PASS_freebayes FILTER_PASS_mutect FILTER_PASS_vardict  \
# 0     1  10177                 False                NaN                 NaN
# 1     1  10352                 False                NaN               False
# 2     1  10583                 False                NaN               False
# 3     1  10623                  True                NaN               False
# 4     1  10649                 False                NaN               False
#
#   FILTER_PASS_varscan
# 0               False
# 1               False
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
df_merged = m3

# %%
# add third category instead of False?
df_merged["FILTER_PASS_freebayes"].fillna(False, inplace=True)
df_merged["FILTER_PASS_vardict"].fillna(False, inplace=True)
df_merged["FILTER_PASS_mutect"].fillna(False, inplace=True)
df_merged["FILTER_PASS_varscan"].fillna(False, inplace=True)
df_merged.head()[["CHROM", "POS", "FILTER_PASS_freebayes", "FILTER_PASS_mutect", "FILTER_PASS_vardict", "FILTER_PASS_varscan"]]
# Out:
#   CHROM    POS  FILTER_PASS_freebayes  FILTER_PASS_mutect  \
# 0     1  10177                  False               False
# 1     1  10352                  False               False
# 2     1  10583                  False               False
# 3     1  10623                   True               False
# 4     1  10649                  False               False
#
#    FILTER_PASS_vardict  FILTER_PASS_varscan
# 0                False                False
# 1                False                False
# 2                False                False
# 3                False                False
# 4                False                False

# %%
truth = pd.read_csv(vcf_folder + "syn3_truth.bed", sep = "\t", header = None)
truth.columns = ["CHROM", "POS_START", "POS_END"]
truth.head()
# Out:
#   CHROM  POS_START  POS_END
# 0     1     836343   836343
# 1     1    1259680  1259680
# 2     1    2165452  2165452
# 3     1    2361895  2361895
# 4     1    2427551  2427551

# %%
(truth.POS_START == truth.POS_END).sum()
# Out:
# 7903

# %%
truth.shape
# Out:
# (7903, 3)

# %%
truth.merge(df_merged, left_on = ["CHROM", "POS_START"], right_on = ["CHROM", "POS"])
# this is smaller than the actual truth file indicating the all 4 variant callers missed to classify some true variants
# Out:
#      CHROM  POS_START    POS_END        POS ID_freebayes REF_freebayes  \
# 0        1     836343     836343     836343            .             C
# 1        1    1259680    1259680    1259680            .             G
# 2        1    2165452    2165452    2165452            .             A
# 3        1    2361895    2361895    2361895            .             T
# 4        1    2427551    2427551    2427551            .             A
# ...    ...        ...        ...        ...          ...           ...
# 7762     X  153972172  153972172  153972172            .             T
# 7763     X  154251600  154251600  154251600            .             C
# 7764     X  154622153  154622153  154622153            .             A
# 7765     X  154635072  154635072  154635072            .             T
# 7766     X  154969106  154969106  154969106            .             T
#
#      ALT_1_freebayes ALT_2_freebayes ALT_3_freebayes  QUAL_freebayes  ...  \
# 0                  A             NaN             NaN      399.200012  ...
# 1                  A             NaN             NaN       77.599998  ...
# 2                  T             NaN             NaN       90.800003  ...
# 3                  C             NaN             NaN      382.299988  ...
# 4                  T             NaN             NaN      185.399994  ...
# ...              ...             ...             ...             ...  ...
# 7762               C             NaN             NaN      128.100006  ...
# 7763               A             NaN             NaN        6.300000  ...
# 7764               C             NaN             NaN      156.899994  ...
# 7765               C             NaN             NaN       48.000000  ...
# 7766               A             NaN             NaN      576.500000  ...
#
#       ALT_3_vardict QUAL_vardict FILTER_PASS_vardict ID_varscan  REF_varscan  \
# 0               NaN        147.0                True          .            C
# 1               NaN         90.0                True        NaN          NaN
# 2               NaN        109.0                True          .            A
# 3               NaN        120.0                True          .            T
# 4               NaN        119.0                True          .            A
# ...             ...          ...                 ...        ...          ...
# 7762            NaN         93.0                True          .            T
# 7763            NaN         51.0                True          .            C
# 7764            NaN        110.0                True          .            A
# 7765            NaN         84.0                True          .            T
# 7766            NaN        154.0                True          .            T
#
#       ALT_1_varscan  ALT_2_varscan  ALT_3_varscan QUAL_varscan  \
# 0                 A            NaN            NaN          0.0
# 1               NaN            NaN            NaN          NaN
# 2                 T            NaN            NaN          0.0
# 3                 C            NaN            NaN          0.0
# 4                 T            NaN            NaN          0.0
# ...             ...            ...            ...          ...
# 7762              C            NaN            NaN          0.0
# 7763              A            NaN            NaN          0.0
# 7764              C            NaN            NaN          0.0
# 7765              C            NaN            NaN          0.0
# 7766              A            NaN            NaN          0.0
#
#      FILTER_PASS_varscan
# 0                  False
# 1                  False
# 2                   True
# 3                  False
# 4                   True
# ...                  ...
# 7762               False
# 7763                True
# 7764                True
# 7765                True
# 7766               False
#
# [7767 rows x 32 columns]

# %%
df_merged_with_truth = pd.merge(truth, df_merged, left_on=["CHROM", "POS_START"], right_on = ["CHROM", "POS"], how="outer")
df_merged_with_truth.head()
# Out:
#   CHROM  POS_START    POS_END        POS ID_freebayes REF_freebayes  \
# 0     1   836343.0   836343.0   836343.0            .             C
# 1     1  1259680.0  1259680.0  1259680.0            .             G
# 2     1  2165452.0  2165452.0  2165452.0            .             A
# 3     1  2361895.0  2361895.0  2361895.0            .             T
# 4     1  2427551.0  2427551.0  2427551.0            .             A
#
#   ALT_1_freebayes ALT_2_freebayes ALT_3_freebayes  QUAL_freebayes  ...  \
# 0               A             NaN             NaN      399.200012  ...
# 1               A             NaN             NaN       77.599998  ...
# 2               T             NaN             NaN       90.800003  ...
# 3               C             NaN             NaN      382.299988  ...
# 4               T             NaN             NaN      185.399994  ...
#
#   ALT_3_vardict QUAL_vardict FILTER_PASS_vardict ID_varscan  REF_varscan  \
# 0           NaN        147.0                True          .            C
# 1           NaN         90.0                True        NaN          NaN
# 2           NaN        109.0                True          .            A
# 3           NaN        120.0                True          .            T
# 4           NaN        119.0                True          .            A
#
#    ALT_1_varscan  ALT_2_varscan ALT_3_varscan QUAL_varscan FILTER_PASS_varscan
# 0              A            NaN           NaN          0.0               False
# 1            NaN            NaN           NaN          NaN               False
# 2              T            NaN           NaN          0.0                True
# 3              C            NaN           NaN          0.0               False
# 4              T            NaN           NaN          0.0                True
#
# [5 rows x 32 columns]

# %%
df_merged_with_truth.shape
# Out:
# (5633223, 32)

# %%
def set_true_label(row):
    if str(row) == "nan":
        return False
    else:
        return True

# %%
df_merged_with_truth["truth"] = df_merged_with_truth["POS_START"].apply(lambda row:set_true_label(row))

# %%
extras_in_truth = df_merged_with_truth[df_merged_with_truth.POS.isna()].index
extras_in_truth
# Out:
# Int64Index([  64,  137,  278,  290,  356,  360,  361,  415,  440,  450,
#             ...
#             7215, 7287, 7401, 7466, 7636, 7686, 7744, 7791, 7816, 7817],
#            dtype='int64', length=136)

# %%
df_merged_with_truth.drop(extras_in_truth, inplace=True)

# %%
df_merged_with_truth.isna().sum()
# Out:
# CHROM                          0
# POS_START                5625320
# POS_END                  5625320
# POS                            0
# ID_freebayes              763553
# REF_freebayes             763553
# ALT_1_freebayes           763553
# ALT_2_freebayes          5555870
# ALT_3_freebayes          5627961
# QUAL_freebayes            763556
# FILTER_PASS_freebayes          0
# ID_mutect                5513007
# REF_mutect               5513007
# ALT_1_mutect             5513007
# ALT_2_mutect             5633087
# ALT_3_mutect             5633087
# QUAL_mutect              5633087
# FILTER_PASS_mutect             0
# ID_vardict                702059
# REF_vardict               702059
# ALT_1_vardict             702059
# ALT_2_vardict            5633087
# ALT_3_vardict            5633087
# QUAL_vardict              702144
# FILTER_PASS_vardict            0
# ID_varscan                913642
# REF_varscan               913642
# ALT_1_varscan             913642
# ALT_2_varscan            5633087
# ALT_3_varscan            5633087
# QUAL_varscan              913642
# FILTER_PASS_varscan            0
# truth                          0
# dtype: int64

# %%
df_merged_with_truth["QUAL_freebayes"].fillna(df_merged_with_truth["QUAL_freebayes"].mean(), inplace=True)
df_merged_with_truth["QUAL_vardict"].fillna(df_merged_with_truth["QUAL_vardict"].mean(), inplace=True)

# %%
df_merged_with_truth["QUAL_mutect"].isna().sum()
# Out:
# 5633087

# %%
df_merged_with_truth[["QUAL_freebayes", "QUAL_vardict"]].corr()
# Out:
#                 QUAL_freebayes  QUAL_vardict
# QUAL_freebayes         1.00000       0.46558
# QUAL_vardict           0.46558       1.00000

# %% [markdown]
# #### Confusion matrix comparing against truth

# %%
from sklearn.metrics import confusion_matrix

# %%
tn, fp, fn, tp = confusion_matrix(list(df_merged_with_truth.truth), list(df_merged_with_truth.FILTER_PASS_freebayes)).ravel()
tn, fp, fn, tp
# Out:
# (5610804, 14516, 792, 6975)

# %%
# least false positives
tn, fp, fn, tp = confusion_matrix(list(df_merged_with_truth.truth), list(df_merged_with_truth.FILTER_PASS_mutect)).ravel()
tn, fp, fn, tp
# Out:
# (5610787, 14533, 317, 7450)

# %%
tn, fp, fn, tp = confusion_matrix(list(df_merged_with_truth.truth), list(df_merged_with_truth.FILTER_PASS_vardict)).ravel()
tn, fp, fn, tp
# Out:
# (5598204, 27116, 354, 7413)

# %%
tn, fp, fn, tp = confusion_matrix(list(df_merged_with_truth.truth), list(df_merged_with_truth.FILTER_PASS_varscan)).ravel()
tn, fp, fn, tp
# Out:
# (5569081, 56239, 3185, 4582)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_merged_with_truth[["FILTER_PASS_mutect", "FILTER_PASS_freebayes", "FILTER_PASS_vardict", "FILTER_PASS_varscan"]], df_merged_with_truth["truth"], test_size = 0.2, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4506469, 4)
# (1126618, 4)
# (4506469,)
# (1126618,)

# %%
from pgmpy.models import BayesianNetwork

# %%
bn = BayesianNetwork(
[
#     ("CHROM", "truth"),
#     ("POS", "truth"),
#     ("QUAL_freebayes", "truth"),
#     ("QUAL_vardict", "truth"),
    ("FILTER_PASS_mutect", "truth"),
    ("FILTER_PASS_freebayes", "truth"),
    ("FILTER_PASS_vardict", "truth"),
    ("FILTER_PASS_varscan", "truth"),
])

# %%
from pgmpy.estimators import MaximumLikelihoodEstimator

# %%
train_df = pd.DataFrame(X_train, columns = ["FILTER_PASS_mutect","FILTER_PASS_freebayes", "FILTER_PASS_vardict", "FILTER_PASS_varscan"])
train_df["truth"] = y_train
print(train_df.shape)
train_df.head()
# Out:
# (4506469, 5)
#         FILTER_PASS_mutect FILTER_PASS_freebayes FILTER_PASS_vardict  \
# 2145709              False                 False               False
# 1865946              False                 False               False
# 1972438              False                 False               False
# 3718546              False                 False               False
# 5502173              False                 False               False
#
#         FILTER_PASS_varscan  truth
# 2145709               False  False
# 1865946               False  False
# 1972438               False  False
# 3718546               False  False
# 5502173               False  False

# %%
bn.fit(
    data=train_df,
    estimator=MaximumLikelihoodEstimator
)

# %%
print(bn.get_cpds("truth"))
# Out:
# +-----------------------+-----+-----------------------------+
# | FILTER_PASS_freebayes | ... | FILTER_PASS_freebayes(True) |
# +-----------------------+-----+-----------------------------+
# | FILTER_PASS_mutect    | ... | FILTER_PASS_mutect(True)    |
# +-----------------------+-----+-----------------------------+
# | FILTER_PASS_vardict   | ... | FILTER_PASS_vardict(True)   |
# +-----------------------+-----+-----------------------------+
# | FILTER_PASS_varscan   | ... | FILTER_PASS_varscan(True)   |
# +-----------------------+-----+-----------------------------+
# | truth(False)          | ... | 0.368268113134444           |
# +-----------------------+-----+-----------------------------+
# | truth(True)           | ... | 0.631731886865556           |
# +-----------------------+-----+-----------------------------+

# %%
test_df = pd.DataFrame(X_test, columns = ["FILTER_PASS_mutect","FILTER_PASS_freebayes", "FILTER_PASS_vardict", "FILTER_PASS_varscan"])
test_df["truth"] = y_test
print(test_df.shape)
test_df.head()
# Out:
# (1126618, 5)
#         FILTER_PASS_mutect FILTER_PASS_freebayes FILTER_PASS_vardict  \
# 3503896              False                 False               False
# 1651373              False                 False               False
# 4984763              False                 False               False
# 3127666              False                 False               False
# 511369               False                 False               False
#
#         FILTER_PASS_varscan  truth
# 3503896               False  False
# 1651373               False  False
# 4984763               False  False
# 3127666               False  False
# 511369                False  False

# %%
from pgmpy.inference import VariableElimination
from ipywidgets import FloatProgress

# %%
bn_infer = VariableElimination(bn)

# %%
from IPython.display import clear_output

# %%
def get_preds(row):
    prob = bn_infer.query(variables=["truth"], evidence={"FILTER_PASS_freebayes": row["FILTER_PASS_freebayes"], \
                                             "FILTER_PASS_mutect": row["FILTER_PASS_mutect"], \
                                             "FILTER_PASS_vardict": row["FILTER_PASS_vardict"], \
                                             "FILTER_PASS_varscan": row["FILTER_PASS_varscan"]}, show_progress=False)
#     clear_output(wait=True)
    if (prob.values[1]) > 0.5:
        return True
    else:
        return False

# %%
test_df["preds"] = test_df.apply(get_preds, axis = 1)

# %% [markdown]
# #### Metric evaluation

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(test_df["truth"], test_df["preds"]))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00   1125060
#         True       0.58      0.89      0.70      1558
#
#     accuracy                           1.00   1126618
#    macro avg       0.79      0.94      0.85   1126618
# weighted avg       1.00      1.00      1.00   1126618
